# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

print(nyt_api_key)
# Out:
# ENTER YOUR KEY HERE

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query = f"{url}q={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&page={page}&api-key={nyt_api_key}"

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time
    query = f"{url}q={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&page={page}&api-key={nyt_api_key}"
    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for doc in response["response"]["docs"]:
            reviews_list.append(doc)
        # Print the page that was just retrieved
        print(f"Retrieved page {page}")
    except:
        # Print the page number that had no results then break from the loop
        print(f"No results found for page {page}")
        break
# Out:
# No results found for page 0

# %%
# Preview the first 5 results in JSON format
print(json.dumps(response, indent=4)[:500])
# Out:
# {
#     "fault": {
#         "faultstring": "Invalid ApiKey",
#         "detail": {
#             "errorcode": "oauth.v2.InvalidApiKey"
#         }
#     }
# }

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0

# Example list of movie titles
titles = ['The Attachment Diaries',
 'What’s Love Got to Do With It?’ Probably a Lo',
 'You Can Live Forever',
 'A Tourist’s Guide to Love',
 'Other People’s Children',
 'One True Loves',
 'The Lost Weekend: A Love Story',
 'A Thousand and One',
 'Your Place or Mine',
 'Love in the Time of Fentanyl',
 'Pamela, a Love Story',
 'In From the Side',
 'After Love',
 'Alcarràs',
 'Nelly & Nadine',
 'Lady Chatterley’s Lover',
 'The Sound of Christmas',
 'The Inspection',
 'Bones and All',
 'My Policeman',
 'About Fate',
 'Waiting for Bojangles',
 'I Love My Dad',
 'A Love Song',
 'Alone Together',
 'Art of Love',
 'The Wheel',
 'Thor: Love and Thunder',
 'Both Sides of the Blade',
 'Fire of Love',
 'Love & Gelato',
 'Stay Prayed Up',
 'Benediction',
 'Dinner in America',
 'In a New York Minute',
 'Anaïs in Love',
 'I Love America',
 'See You Then',
 'La Mami',
 'Love After Love',
 'Deep Water',
 'Lucy and Desi',
 'Cyrano',
 'The In Between',
 'Book of Love',
 'Lingui, the Sacred Bonds',
 'The Pink Cloud',
 'A Journal for Jordan',
 'West Side Story',
 'Aulcie',
 'Love Is Love Is Love',
 'Love Hard',
 'Bergman Island',
 'Hard Luck Love Song',
 'South of Heaven',
 'Wife of a Spy',
 'Happier Than Ever',
 'Together',
 'Annette',
 'Resort to Love',
 'Woodstock 99: Peace, Love and Rage',
 'Casanova, Last Love',
 'Running Against the Wind',
 'Asia',
 'Undine',
 'This Town',
 'Tu Me Manques',
 'Monday',
 'Ride or Die',
 'Future People',
 'Luz',
 'Happily',
 'This Is the Life',
 'To All the Boys: Always and Forever',
 'Young Hearts',
 'Little Fish',
 'Two of Us',
 'Atlantis',
 'Preparations to Be Together',
 'Your Name Engraved Herein',
 'Sylvie’s Love',
 'Ariana Grande: Excuse Me, I Love You',
 'Museum Town',
 'Wild Mountain Thyme',
 'My Psychedelic Love Story',
 '69: The Saga of Danny Hernandez',
 'Ammonite',
 'Love and Monsters',
 'Dick Johnson Is Dead',
 'Love, Guaranteed',
 'Feel the Beat',
 'Babyteeth',
 'Spelling the Dream',
 'A Secret Love',
 'Love Wedding Repeat',
 'Almost Love',
 'Hope Gap',
 'All the Bright Places',
 'The Photograph',
 'You Go to My Head',
 'Ordinary Love',
 'To All the Boys: P.S. I Still Love You',
 'The Woman Who Loves Giraffes',
 'Queen & Slim',
 'Marriage Story',
 'Cyrano, My Love',
 'Pretenders',
 'First Love',
 'Loro',
 'Falling Inn Love',
 'Hot Air',
 'Love, Antosha',
 'Leto',
 'The Tomorrow Man',
 'Asako I & II',
 'The Sun Is Also a Star',
 'Shéhérazade',
 'Long Shot',
 'Clara',
 'Kalank',
 'Rafiki',
 'Diane',
 'Five Feet Apart',
 'Ash Is Purest White',
 'Gloria Bell',
 'Black Mother',
 'The Hole in the Ground',
 'How to Train Your Dragon: The Hidden World',
 'A Tuba to Cuba',
 'Fighting With My Family',
 'Sorry Angel',
 'Berlin, I Love You',
 'Untogether',
 'Cold War',
 'If Beale Street Could Talk',
 'Asher',
 'The Party’s Just Beginning',
 'The Great Pretender',
 'Sicilian Ghost Story',
 'The New Romantic',
 'Pimp',
 'In a Relationship',
 'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
 'Burning,’ Love Ignites a Divided Worl',
 'After Everything,’ a Young Love Blooms in Crisi',
 'Quincy’ Captures a Lifelong Love Affair With Musi',
 'Love, Gilda,’ a Portrait of a Brief and Brilliant Caree',
 'Tea With the Dames,’ Four Legends Dish on Acting and Lov',
 'Bel Canto,’ Music Is the Food of Love and Rebellio',
 'The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov',
 'Love, Cecil,’ an Aesthete Ahead of His Tim',
 'How to Talk to Girls at Parties',
 'Rogers Park,’ Life and Love in a Chicago Neighborhoo',
 'Love & Bananas,’ Uncovering the Plight of the Asian Elephan',
 'Godard Mon Amour',
 'Submergence,’ a Love Story Sunk by Geopolitic',
 'Love After Love,’ an Unflinching Look at Extended Grie',
 'Outside In',
 'Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre',
 'Keep the Change,’ Two People With Autism Find Lov',
 'The Party',
 'The Housemaid,’ Twisted Love and Angry Ghosts in Vietna',
 'Forever My Girl,’ a Romance Resumes After a Long Brea',
 'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
 'Lover for a Day',
 'Youth,’ the People’s Dance Troupe, in Love and Wa',
 'Killing for Love’ Revisits a Virginia Murder Cas',
 'The Shape of Water’ Is Altogether Wonderfu',
 'Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr',
 'Cuba and the Cameraman’ Lavishes Love on a Country … and Castr',
 'On the Beach at Night Alone’ Zooms in on a Love Affai',
 'Thelma,’ a Woman in Love Can Burn Down the Worl',
 'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade',
 'It Happened in L.A.,’ All That Questing After Lov',
 'God’s Own Country',
 'The Mountain Between Us',
 'Dina,’ a Differently Abled Love Stor',
 'In Search of Fellini',
 'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen',
 'I Do ... Until I Don’t,’ Love and Loathing in Florid',
 'Tales of an Immoral Couple’: Love Means Having to Grow U',
 'After Love’ and Regretting Every Momen',
 'The Last Face',
 'Women Who Kill,’ and May Be in Love With On',
 'False Confessions,’ the Play’s Not Quite the Thin',
 'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem',
 'The Big Sick,’ Comedy Is Hard, Love Harde',
 'Lost in Paris',
 'Vincent N Roxxy,’ Love Is in the Air, N So Is Fea',
 'Everything, Everything’ Pits Love Against Diseas',
 'Hounds of Love’ Is Tense and Deadly Down Unde',
 'Harold and Lillian’ Introduces a Hollywood Power Coupl',
 'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope',
 'The Promise’ Finds a Love Triangle in Constantinopl',
 'Frantz,’ a Mysterious Frenchman and the Wounds of Wa',
 'The Other Half',
 'The Ottoman Lieutenant',
 'Love & Taxes',
 'Everybody Loves Somebody,’ a Rom-Com With Bit',
 'Kedi,’ Rekindling a ‘Love of Life']

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(10)
    
    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(url + title + tmdb_key_string).json()
    
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = response['results'][0]['id']
        
        # Make a request for the full movie details
        movie_details = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}").json()
        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in movie_details['genres']]
        
        # Extract the spoken_languages' English name into a list
        spoken_languages = [language['english_name'] for language in movie_details['spoken_languages']]
        
        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in movie_details['production_countries']]
        
        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_data = {
            'title': title,
            'genres': genres,
            'spoken_languages': spoken_languages,
            'production_countries': production_countries
        }
        tmdb_movies_list.append(movie_data)
        
        # Print out the title that was found
        print(f"Found movie: {title}")
    except:
        print(f"Movie not found: {title}")
# Out:
# Movie not found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Movie not found: You Can Live Forever
# Movie not found: A Tourist’s Guide to Love
# Movie not found: Other People’s Children
# Movie not found: One True Loves
# Movie not found: The Lost Weekend: A Love Story
# Movie not found: A Thousand and One
# Movie not found: Your Place or Mine
# Movie not found: Love in the Time of Fentanyl
# Movie not found: Pamela, a Love Story
# Movie not found: In From the Side
# Movie not found: After Love
# Movie not found: Alcarràs
# Movie not found: Nelly & Nadine
# Movie not found: Lady Chatterley’s Lover
# Movie not found: The Sound of Christmas
# Movie not found: The Inspection
# Movie not found: Bones and All
# Movie not found: My Policeman
# Movie not found: About Fate
# Movie not found: Waiting for Bojangles
# Movie not found: I Love My Dad
# Movie not found: A Love Song
# Movie not found: Alone Together
# Movie not found: Art of Love
# Movie not found: The Wheel
# Movie not found: Thor: Love and Thunder
# Movie not found: Both Sides of the Blade
# Movie not found: Fire of Love
# Movie not found: Love & Gelato
# Movie not found: Stay Prayed Up
# Movie not found: Benediction
# Movie not found: Dinner in America
# Movie not found: In a New York Minute
# Movie not found: Anaïs in Love
# Movie not found: I Love America
# Movie not found: See You Then
# Movie not found: La Mami
# Movie not found: Love After Love
# Movie not found: Deep Water
# Movie not found: Lucy and Desi
# Movie not found: Cyrano
# Movie not found: The In Between
# Movie not found: Book of Love
# Movie not found: Lingui, the Sacred Bonds
# Movie not found: The Pink Cloud
# Movie not found: A Journal for Jordan
# Movie not found: West Side Story
# Movie not found: Aulcie
# Movie not found: Love Is Love Is Love
# Movie not found: Love Hard
# Movie not found: Bergman Island
# Movie not found: Hard Luck Love Song
# Movie not found: South of Heaven
# Movie not found: Wife of a Spy
# Movie not found: Happier Than Ever
# Movie not found: Together
# Movie not found: Annette
# Movie not found: Resort to Love
# Movie not found: Woodstock 99: Peace, Love and Rage
# Movie not found: Casanova, Last Love
# Movie not found: Running Against the Wind
# Movie not found: Asia
# Movie not found: Undine
# Movie not found: This Town
# Movie not found: Tu Me Manques
# Movie not found: Monday
# Movie not found: Ride or Die
# Movie not found: Future People
# Movie not found: Luz
# Movie not found: Happily
# Movie not found: This Is the Life
# Movie not found: To All the Boys: Always and Forever
# Movie not found: Young Hearts
# Movie not found: Little Fish
# Movie not found: Two of Us
# Movie not found: Atlantis
# Movie not found: Preparations to Be Together
# Movie not found: Your Name Engraved Herein
# Movie not found: Sylvie’s Love
# Movie not found: Ariana Grande: Excuse Me, I Love You
# Movie not found: Museum Town
# Movie not found: Wild Mountain Thyme
# Movie not found: My Psychedelic Love Story
# Movie not found: 69: The Saga of Danny Hernandez
# Movie not found: Ammonite
# Movie not found: Love and Monsters
# Movie not found: Dick Johnson Is Dead
# Movie not found: Love, Guaranteed
# Movie not found: Feel the Beat
# Movie not found: Babyteeth
# Movie not found: Spelling the Dream
# Movie not found: A Secret Love
# Movie not found: Love Wedding Repeat
# Movie not found: Almost Love
# Movie not found: Hope Gap
# Movie not found: All the Bright Places
# Movie not found: The Photograph
# Movie not found: You Go to My Head
# Movie not found: Ordinary Love
# Movie not found: To All the Boys: P.S. I Still Love You
# Movie not found: The Woman Who Loves Giraffes
# Movie not found: Queen & Slim
# Movie not found: Marriage Story
# Movie not found: Cyrano, My Love
# Movie not found: Pretenders
# Movie not found: First Love
# Movie not found: Loro
# Movie not found: Falling Inn Love
# Movie not found: Hot Air
# Movie not found: Love, Antosha
# Movie not found: Leto
# Movie not found: The Tomorrow Man
# Movie not found: Asako I & II
# Movie not found: The Sun Is Also a Star
# Movie not found: Shéhérazade
# Movie not found: Long Shot
# Movie not found: Clara
# Movie not found: Kalank
# Movie not found: Rafiki
# Movie not found: Diane
# Movie not found: Five Feet Apart
# Movie not found: Ash Is Purest White
# Movie not found: Gloria Bell
# Movie not found: Black Mother
# Movie not found: The Hole in the Ground
# Movie not found: How to Train Your Dragon: The Hidden World
# Movie not found: A Tuba to Cuba
# Movie not found: Fighting With My Family
# Movie not found: Sorry Angel
# Movie not found: Berlin, I Love You
# Movie not found: Untogether
# Movie not found: Cold War
# Movie not found: If Beale Street Could Talk
# Movie not found: Asher
# Movie not found: The Party’s Just Beginning
# Movie not found: The Great Pretender
# Movie not found: Sicilian Ghost Story
# Movie not found: The New Romantic
# Movie not found: Pimp
# Movie not found: In a Relationship
# Movie not found: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# Movie not found: Burning,’ Love Ignites a Divided Worl
# Movie not found: After Everything,’ a Young Love Blooms in Crisi
# Movie not found: Quincy’ Captures a Lifelong Love Affair With Musi
# Movie not found: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# Movie not found: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# Movie not found: Bel Canto,’ Music Is the Food of Love and Rebellio
# Movie not found: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# Movie not found: Love, Cecil,’ an Aesthete Ahead of His Tim
# Movie not found: How to Talk to Girls at Parties
# Movie not found: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Movie not found: Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Movie not found: Godard Mon Amour
# Movie not found: Submergence,’ a Love Story Sunk by Geopolitic
# Movie not found: Love After Love,’ an Unflinching Look at Extended Grie
# Movie not found: Outside In
# Movie not found: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# Movie not found: Keep the Change,’ Two People With Autism Find Lov
# Movie not found: The Party
# Movie not found: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# Movie not found: Forever My Girl,’ a Romance Resumes After a Long Brea
# Movie not found: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Movie not found: Lover for a Day
# Movie not found: Youth,’ the People’s Dance Troupe, in Love and Wa
# Movie not found: Killing for Love’ Revisits a Virginia Murder Cas
# Movie not found: The Shape of Water’ Is Altogether Wonderfu
# Movie not found: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# Movie not found: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# Movie not found: On the Beach at Night Alone’ Zooms in on a Love Affai
# Movie not found: Thelma,’ a Woman in Love Can Burn Down the Worl
# Movie not found: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# Movie not found: It Happened in L.A.,’ All That Questing After Lov
# Movie not found: God’s Own Country
# Movie not found: The Mountain Between Us
# Movie not found: Dina,’ a Differently Abled Love Stor
# Movie not found: In Search of Fellini
# Movie not found: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# Movie not found: I Do ... Until I Don’t,’ Love and Loathing in Florid
# Movie not found: Tales of an Immoral Couple’: Love Means Having to Grow U
# Movie not found: After Love’ and Regretting Every Momen
# Movie not found: The Last Face
# Movie not found: Women Who Kill,’ and May Be in Love With On
# Movie not found: False Confessions,’ the Play’s Not Quite the Thin
# Movie not found: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# Movie not found: The Big Sick,’ Comedy Is Hard, Love Harde
# Movie not found: Lost in Paris
# Movie not found: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Movie not found: Everything, Everything’ Pits Love Against Diseas
# Movie not found: Hounds of Love’ Is Tense and Deadly Down Unde
# Movie not found: Harold and Lillian’ Introduces a Hollywood Power Coupl
# Movie not found: The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope
# Movie not found: The Promise’ Finds a Love Triangle in Constantinopl
# Movie not found: Frantz,’ a Mysterious Frenchman and the Wounds of Wa
# Movie not found: The Other Half
# Movie not found: The Ottoman Lieutenant
# Movie not found: Love & Taxes
# Movie not found: Everybody Loves Somebody,’ a Rom-Com With Bit
# Movie not found: Kedi,’ Rekindling a ‘Love of Life

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(response['response']['docs'][:5], indent=4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Preview the first 5 results in JSON format
#       2 # Use json.dumps with argument indent=4 to format data
# ----> 3 print(json.dumps(response['response']['docs'][:5], indent=4))
#
# KeyError: 'response'

# %%
# Convert the results to a DataFrame

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
